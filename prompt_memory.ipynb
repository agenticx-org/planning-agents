# %%
from smolagents import tool
from typing import Optional, List, Union
import pandas as pd
import networkx as nx
import itertools

def convert_entities_to_json(row):
    # Initialize a dictionary to hold the entities grouped by their type
    entities_list = row['entities']
    entity_dict = {}

    entity_dict['timestamp'] = row['created_at']
    entity_dict['raw_text'] = row['text']


    for entity in entities_list:
        label = entity['label']
        text = entity['text']

        if label not in entity_dict:
            entity_dict[label] = ""

        # Append the entity text to the list of its corresponding type
        if len(entity_dict[label]) == 0:
            entity_dict[label] += text
        else:
            entity_dict[label] += ", "+text

    # Convert the dictionary to a JSON string
    #json_output = json.dumps(entity_dict, indent=4)
    
    return entity_dict


dataset="dump.pkl"

df = pd.read_pickle(dataset)
df = df[df['entities'].apply(lambda x: len(x) > 0)]
df = pd.DataFrame(df.apply(convert_entities_to_json, axis=1).to_list()).fillna("")

@tool
def load_filter_dataframe(
    start_time: Optional[str] = None,
    end_time: Optional[str] = None,
    match_columns: Optional[object] = None,  # Explicitly Optional
    match_strings: Optional[object] = None   # Explicitly Optional
) -> pd.DataFrame:
    """
    Filters the DataFrame based on an optional time range and text matches.

    Args:
        start_time: The starting timestamp to filter data from (format: 'YYYY-MM-DD HH:MM:SS').
        end_time: The ending timestamp to filter data until (format: 'YYYY-MM-DD HH:MM:SS').
        match_columns: A list of column names to search for matches (nullable).
        match_strings: Strings to match in the specified columns (nullable).

    Returns:
        Filtered pandas DataFrame containing only rows that match all criteria.

    Example:
        filter_dataframe(
            start_time='2023-01-01 00:00:00',
            end_time='2023-01-31 23:59:59',
            match_columns=['text', 'title'],
            match_strings=[['ai', 'machine learning', 'artificial intelligence', 'neural']])
    """
    global df
    
    # Convert timestamps
    if 'timestamp' in df.columns:
        df['timestamp'] = pd.to_datetime(df['timestamp'])

    # Apply time filtering if start_time and/or end_time are provided
    if start_time is not None or end_time is not None:
        if start_time is not None:
            try:
                start_time = pd.to_datetime(start_time)
            except Exception as e:
                raise ValueError(f"Invalid start_time format: {e}")
        
        if end_time is not None:
            try:
                end_time = pd.to_datetime(end_time)
            except Exception as e:
                raise ValueError(f"Invalid end_time format: {e}")

        # Apply the time range filter
        if start_time and end_time:
            df = df[(df['timestamp'] >= start_time) & (df['timestamp'] <= end_time)]
        elif start_time:
            df = df[df['timestamp'] >= start_time]
        elif end_time:
            df = df[df['timestamp'] <= end_time]

    # Apply text matching if match_columns and match_strings are provided
    if match_columns and match_strings:
        # Ensure match_strings is a list of lists if it's not already structured that way
        if isinstance(match_strings[0], str):
            match_strings = [match_strings]

        for column, strings in zip(match_columns, match_strings):
            if column in df.columns:
                # Use any() to check if any of the specified strings are present (case-insensitive)
                condition = df[column].apply(
                    lambda x: any(
                        s.lower() in str(item).lower()
                        for s in strings
                        for item in (x if isinstance(x, list) else [x])
                    )
                )
                df = df[condition]
            else:
                raise KeyError(f"Column '{column}' not found in DataFrame.")
    
    return df


@tool
def df_to_network_graph(df: pd.DataFrame, exclude_cols: Optional[object] = ['timestamp', 'raw_text']) -> nx.Graph:
    """
    Transform a DataFrame into a networkx graph where all entities in each row
    are connected to each other.
    
    Args:
        df: The input DataFrame to be transformed into a network graph.
        exclude_cols: Column names to exclude from the graph. Default excludes ['timestamp', 'raw_text'].
    
    Returns:
        A networkx.Graph with edges between entities that appear in the same row.
    """
    # Create empty graph
    
    G = nx.Graph()
    
    # Initialize list to exclude certain columns
    if exclude_cols is None:
        exclude_cols = []
    
    # Process each row
    for _, row in df.iterrows():
        # Get non-null values that aren't in exclude_cols
        entities = [str(row[col]) for col in df.columns 
                  if col not in exclude_cols and pd.notna(row[col])]
        
        # Create edges between all pairs of entities in this row
        for entity1, entity2 in itertools.combinations(entities, 2):
            if G.has_edge(entity1, entity2):
                # If edge exists, increment weight
                G[entity1][entity2]['weight'] += 1
            else:
                # Create new edge with weight 1
                G.add_edge(entity1, entity2, weight=1)
    
    return G




@tool
def write_findings(content: str, file_path: Optional[str] = "findings.md", append: Optional[bool] = False) -> str:
    """
    Writes or appends content to a markdown findings file.
    
    Args:
        content: The content to write to the file
        file_path: Path to the findings.md file. Defaults to 'findings.md'
        append: If True, appends to the file; if False, overwrites the file
        
    Returns:
        A message indicating success or failure
    """
    try:
        mode = 'a' if append else 'w'
        with open(file_path, mode) as file:
            file.write(content)
        return f"Successfully {'appended to' if append else 'wrote'} {file_path}"
    except Exception as e:
        return f"Error writing to file: {str(e)}"

@tool
def write_plan_file(content: str, file_path: Optional[str] = "plan.md", append: Optional[bool] = False) -> str:
    """
    Writes or appends content to a markdown plan file.
    
    Args:
        content: The content to write to the file
        file_path: Path to the plan.md file. Defaults to 'plan.md'
        append: If True, appends to the file; if False, overwrites the file
        
    Returns:
        A message indicating success or failure
    """
    try:
        mode = 'a' if append else 'w'
        with open(file_path, mode) as file:
            file.write(content)
        return f"Successfully {'appended to' if append else 'wrote'} {file_path}"
    except Exception as e:
        return f"Error writing to file: {str(e)}"

# %%
from smolagents.prompts import CODE_SYSTEM_PROMPT

#write_plan_file(CODE_SYSTEM_PROMPT)

# %%
new_prompt = """
You are an expert research assistant who can solve any task using code blobs. You will be given a task to solve as best you can.
To do so, you have been given access to a list of tools: these tools are basically Python functions which you can call with code.
To solve the task, you must plan forward to proceed in a series of steps, in a cycle of 'Thought:', 'Code:', and 'Observation:' sequences.

At each step, in the 'Thought:' sequence, you need to create/refine your plan in a structured markdown way. Putting a check where you've explored with some notes under each section.

# Research Agent Progress Tracking

## Completed Milestones
- [x] Initial project conception and research objective formulation
- [x] Comprehensive literature review on entity extraction and data processing methods
- [x] Proof of concept for Named Entity Recognition (NER) extraction using the Twitter/X dataset
- [x] Preliminary development of an entity and relation extraction prototype

## Current Research Focus
### Data Acquisition and Processing
- [x] Integration and cleaning of the Twitter/X dataset
- [x] Implementation of GLiNER for initial entity extraction
- [ ] Refinement of the entity taxonomy based on recent literature insights
- [ ] Optimization of relation extraction methodologies through iterative testing

Create a plan if there is no plan, update the plan after every observation. 

Then in the 'Code:' sequence, you should write the code in simple Python. The code sequence must end with '' sequence.
During each intermediate step, you can use 'print()' to save whatever important information you will then need.
These print outputs will then appear in the 'Observation:' field, which will be available as input for the next step.
In the end you have to return a final answer using the `final_answer` tool.

Here are a few examples using notional tools:
---
Task: "Generate an image of the oldest person in this document."

Thought: 
# Task Progress Tracking

## Completed Milestones
- [x] Initial task analysis

## Current Focus
### Information Gathering
- [ ] Identify the oldest person in the document
- [ ] Generate an appropriate image description
- [ ] Create final image

I'll proceed step by step, first using `document_qa` to find the oldest person mentioned in the document.

Code:
```
answer = document_qa(document=document, question="Who is the oldest person mentioned?")
print(answer)
```
Observation: "The oldest person in the document is John Doe, a 55 year old lumberjack living in Newfoundland."

Thought:
# Task Progress Tracking

## Completed Milestones
- [x] Initial task analysis
- [x] Identified the oldest person in the document (John Doe, 55)

## Current Focus
### Image Generation
- [ ] Generate an appropriate image description
- [ ] Create final image

Now that I've identified John Doe as the oldest person, I'll generate an image portraying him.

Code:
```
image = image_generator("A portrait of John Doe, a 55-year-old man living in Canada.")
final_answer(image)
```

---
Task: "What is the result of the following operation: 5 + 3 + 1294.678?"

Thought: 
# Task Progress Tracking

## Completed Milestones
- [x] Parsed mathematical expression

## Current Focus
### Calculation
- [ ] Compute the result (5 + 3 + 1294.678)
- [ ] Return final answer

This is a straightforward calculation task. I'll use Python to compute the result.

Code:
```
result = 5 + 3 + 1294.678
final_answer(result)
```

---
Task:
"Answer the question in the variable `question` about the image stored in the variable `image`. The question is in French.
You have been provided with these additional arguments, that you can access using the keys as variables in your python code:
{'question': 'Quel est l'animal sur l'image?', 'image': 'path/to/image.jpg'}"

Thought: 
# Task Progress Tracking

## Completed Milestones
- [x] Initial task analysis

## Current Focus
### Language Processing
- [ ] Translate the question from French to English
- [ ] Analyze the image with the translated question
- [ ] Format the final answer

I need to first translate the question and then use image analysis to answer it.

Code:
```
translated_question = translator(question=question, src_lang="French", tgt_lang="English")
print(f"The translated question is {translated_question}.")
```
Observation: "The translated question is 'What is the animal in the image?'"

Thought:
# Task Progress Tracking

## Completed Milestones
- [x] Initial task analysis
- [x] Translated the question from French to English

## Current Focus
### Image Analysis
- [ ] Analyze the image with the translated question
- [ ] Format the final answer

Now I'll use the translated question to analyze the image content.

Code:
```
answer = image_qa(image=image, question=translated_question)
final_answer(f"The answer is {answer}")
```

---
Task:
In a 1979 interview, Stanislaus Ulam discusses with Martin Sherwin about other great physicists of his time, including Oppenheimer.
What does he say was the consequence of Einstein learning too much math on his creativity, in one word?

Thought: 
# Task Progress Tracking

## Completed Milestones
- [x] Initial task analysis

## Current Focus
### Information Retrieval
- [ ] Find the 1979 Ulam-Sherwin interview
- [ ] Locate Einstein references in the interview
- [ ] Extract the specific comment about Einstein and mathematics
- [ ] Identify the one-word consequence

I'll begin by searching for this specific interview.

Code:
```
pages = search(query="1979 interview Stanislaus Ulam Martin Sherwin physicists Einstein")
print(pages)
```
Observation:
No result found for query "1979 interview Stanislaus Ulam Martin Sherwin physicists Einstein".

Thought: 
# Task Progress Tracking

## Completed Milestones
- [x] Initial task analysis
- [x] Attempted specific search (unsuccessful)

## Current Focus
### Information Retrieval
- [ ] Try broader search terms for the interview
- [ ] Locate Einstein references in the interview
- [ ] Extract the specific comment about Einstein and mathematics
- [ ] Identify the one-word consequence

The query was too restrictive. I'll try a broader search.

Code:
```
pages = search(query="1979 interview Stanislaus Ulam")
print(pages)
```
Observation:
Found 6 pages:
[Stanislaus Ulam 1979 interview](https://ahf.nuclearmuseum.org/voices/oral-histories/stanislaus-ulams-interview-1979/)... [Ulam discusses Manhattan Project](https://ahf.nuclearmuseum.org/manhattan-project/ulam-manhattan-project/)

Thought: 
# Task Progress Tracking

## Completed Milestones
- [x] Initial task analysis
- [x] Attempted specific search (unsuccessful)
- [x] Found relevant pages with broader search terms

## Current Focus
### Content Analysis
- [ ] Read the interview content from found pages
- [ ] Locate Einstein references in the interview
- [ ] Extract the specific comment about Einstein and mathematics
- [ ] Identify the one-word consequence

I'll examine the content of these pages to find the relevant information.

Code:
```
for url in ["https://ahf.nuclearmuseum.org/voices/oral-histories/stanislaus-ulams-interview-1979/", "https://ahf.nuclearmuseum.org/manhattan-project/ulam-manhattan-project/"]:
    whole_page = visit_webpage(url)
    print(whole_page)
    print("\n" + "="*80 + "\n")  # Print separator between pages
```
Observation:
Manhattan Project Locations:
Los Alamos, NM
Stanislaus Ulam was a Polish-American mathematician. He worked on the Manhattan Project at Los Alamos and later helped design the hydrogen bomb. In this interview, he discusses his work at
(truncated)

Thought: I now have the final answer: from the webpages visited, Stanislaus Ulam says of Einstein: "He learned too much mathematics and sort of diminished, it seems to me personally, it seems to me his purely physics creativity." Let's answer in one word.
Code:
```
final_answer("diminished")
```

---
Task: "Which city has the highest population: Guangzhou or Shanghai?"

Thought: 
# Task Progress Tracking

## Completed Milestones
- [x] Identified cities to compare (Guangzhou and Shanghai)

## Current Focus
### Data Collection
- [ ] Find population data for Guangzhou
- [ ] Find population data for Shanghai
- [ ] Compare populations
- [ ] Determine city with higher population

I need population figures for both cities to make the comparison.

Code:
```
for city in ["Guangzhou", "Shanghai"]:
    print(f"Population {city}:", search(f"{city} population"))
```
Observation:
Population Guangzhou: ['Guangzhou has a population of 15 million inhabitants as of 2021.']
Population Shanghai: '26 million (2019)'

Thought: 
# Task Progress Tracking

## Completed Milestones
- [x] Identified cities to compare (Guangzhou and Shanghai)
- [x] Found population data for Guangzhou (15 million in 2021)
- [x] Found population data for Shanghai (26 million in 2019)
- [x] Compared populations

## Current Focus
### Conclusion
- [ ] Determine city with higher population

Based on the data collected, Shanghai has a higher population (26 million) than Guangzhou (15 million).

Code:
```
final_answer("Shanghai")
```

---
Task: "What is the current age of the pope, raised to the power 0.36?"

Thought: I will use the tool `wiki` to get the age of the pope, and confirm that with a web search.
Code:
```
pope_age_wiki = wiki(query="current pope age")
print("Pope age as per wikipedia:", pope_age_wiki)
pope_age_search = web_search(query="current pope age")
print("Pope age as per google search:", pope_age_search)
```
Observation:
Pope age: "The pope Francis is currently 88 years old."

Thought: I know that the pope is 88 years old. Let's compute the result using python code.
Code:
```
pope_current_age = 88 ** 0.36
final_answer(pope_current_age)
```

Above example were using notional tools that might not exist for you. On top of performing computations in the Python code snippets that you create, you only have access to these tools:

{{tool_descriptions}}

{{managed_agents_descriptions}}

Here are the rules you should always follow to solve your task:
1. Always provide a 'Thought:' sequence, and a 'Code:
``````' sequence, else you will fail.
2. Use only variables that you have defined!
3. Always use the right arguments for the tools. DO NOT pass the arguments as a dict as in 'answer = wiki({'query': "What is the place where James Bond lives?"})', but use the arguments directly as in 'answer = wiki(query="What is the place where James Bond lives?")'.
4. Take care to not chain too many sequential tool calls in the same code block, especially when the output format is unpredictable. For instance, a call to search has an unpredictable return format, so do not have another tool call that depends on its output in the same block: rather output results with print() to use them in the next block.
5. Call a tool only when needed, and never re-do a tool call that you previously did with the exact same parameters.
6. Don't name any new variable with the same name as a tool: for instance don't name a variable 'final_answer'.
7. Never create any notional variables in our code, as having these in your logs will derail you from the true variables.
8. You can use imports in your code, but only from the following list of modules: {{authorized_imports}}
9. The state persists between code executions: so if in one step you've created variables or imported modules, these will all persist.
10. Don't give up! You're in charge of solving the task, not providing directions to solve it.
11. Write your thoughts out using the write_plan_file at the begining of every code block.
12. Update the write_plan_file and write_findings as a second last step just before calling the finish tool.
13. Use [x] and [ ] formatting in the plan
Now Begin! If you solve the task correctly, you will receive a reward of $1,000,000.

"""

# %%
modified_system_prompt = new_prompt

from smolagents import CodeAgent, LiteLLMModel

model = LiteLLMModel(model_id="bedrock/anthropic.claude-3-5-sonnet-20240620-v1:0") # Could use 'gpt-4o'
agent = CodeAgent(tools=[write_findings,write_plan_file,load_filter_dataframe,], model=model,system_prompt=modified_system_prompt, additional_authorized_imports=['pandas','openpyxl','xlrd','os','matplotlib','numpy','statsmodels','PIL','io','base64','sklearn'])

result = agent.run(
    "Could you explore the loaded data frame and tell me what you see?",
)
# Out:
# ╭────────────────────────────────────────────────────────────────────────────────────────────── New run ───────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                                                                                      │
# │ Could you explore the loaded data frame and tell me what you see?                                                                                                                                    │
# │                                                                                                                                                                                                      │
# ╰─ LiteLLMModel - bedrock/anthropic.claude-3-5-sonnet-20240620-v1:0 ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 0 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing this code: ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   # Update the plan
#   write_plan_file('''
#   # Research Agent Progress Tracking
#
#   ## Current Focus
#   ### Data Exploration
#   - [x] Load the data frame
#   - [ ] Examine the data frame structure
#   - [ ] Analyze the content and data types
#   - [ ] Provide a summary of findings
#   ''')
#
#   # Load the data frame without any filters
#   df = load_filter_dataframe()
#
#   # Display basic information about the data frame
#   print("Data frame info:")
#   print(df.info())
#
#   # Display the first few rows
#   print("\nFirst few rows of the data frame:")
#   print(df.head())
#
#   # Display summary statistics
#   print("\nSummary statistics:")
#   print(df.describe())
#
#   # Display column names
#   print("\nColumn names:")
#   print(df.columns.tolist())
#
#   # Display data types of columns
#   print("\nData types of columns:")
#   print(df.dtypes)
#
#   # Display unique values in categorical columns (if any)
#   for col in df.select_dtypes(include=['object']).columns:
#       print(f"\nUnique values in {col}:")
#       print(df[col].unique())
#
#   # Count of null values in each column
#   print("\nNull values count in each column:")
#   print(df.isnull().sum())
#  ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255270 entries, 0 to 255269
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   timestamp           255270 non-null  datetime64[ns, UTC]
#  1   raw_text            255270 non-null  object
#  2   Event               255270 non-null  object
#  3   Company             255270 non-null  object
#  4   Product             255270 non-null  object
#  5   Location            255270 non-null  object
#  6   Growth Trend        255270 non-null  object
#  7   Competitor          255270 non-null  object
#  8   Time                255270 non-null  object
#  9   Financial Metrics   255270 non-null  object
#  10  Neutral Sentiment   255270 non-null  object
#  11  Negative Sentiment  255270 non-null  object
#  12  Regulation          255270 non-null  object
#  13  Country             255270 non-null  object
#  14  Positive Sentiment  255270 non-null  object
#  15  Measures            255270 non-null  object
# dtypes: datetime64[ns, UTC](1), object(15)
# memory usage: 31.2+ MB
# Execution logs:
# Data frame info:
# None
#
# First few rows of the data frame:
#                   timestamp  \
# 0 2020-04-09 23:56:51+00:00
# 1 2020-04-09 23:54:47+00:00
# 2 2020-04-09 23:54:26+00:00
# 3 2020-04-09 23:49:05+00:00
# 4 2020-04-09 23:49:01+00:00
#
#                                             raw_text            Event  \
# 0  $UMRX bouncing. EXTREMELY OVERSOLD #Coronaviru...      Coronavirus
# 1  This week's Expired Signals are now published ...  Expired Signals
# 2  #tradeitforward MTI's Ask An Analyst with Chri...
# 3  RT @CheddarFlow: Some highly unusual orders we...
# 4  RT @LanceRoberts: $JPM has stopped making Smal...
#
#           Company   Product Location Growth Trend Competitor Time  \
# 0             GME
# 1  TGT, MCD, AAPL
# 2        MTI, MTI
# 3     CheddarFlow  SPY, SLV
# 4             JPM
#
#   Financial Metrics Neutral Sentiment Negative Sentiment Regulation Country  \
# 0
# 1
# 2
# 3
# 4
#
#   Positive Sentiment Measures
# 0
# 1
# 2
# 3
# 4
#
# Summary statistics:
#                                   timestamp  \
# count                                255270
# unique                                  NaN
# top                                     NaN
# freq                                    NaN
# mean    2020-05-30 13:13:38.167594752+00:00
# min               2020-04-09 00:00:01+00:00
# 25%     2020-04-28 09:45:56.249999872+00:00
# 50%               2020-06-06 02:20:14+00:00
# 75%     2020-06-26 01:18:39.750000128+00:00
# max               2020-07-16 23:59:03+00:00
#
#                                                  raw_text   Event Company  \
# count                                              255270  255270  255270
# unique                                             223752   11153   75031
# top     RT @eWhispers: #earnings for the week \n\nhttp...
# freq                                                  510  222586   94164
# mean                                                  NaN     NaN     NaN
# min                                                   NaN     NaN     NaN
# 25%                                                   NaN     NaN     NaN
# 50%                                                   NaN     NaN     NaN
# 75%                                                   NaN     NaN     NaN
# max                                                   NaN     NaN     NaN
#
#        Product Location Growth Trend Competitor    Time Financial Metrics  \
# count   255270   255270       255270     255270  255270            255270
# unique   35710     3860         9316      13756   16095             12003
# top
# freq    147895   243709       235643     225436  196256            216162
# mean       NaN      NaN          NaN        NaN     NaN               NaN
# min        NaN      NaN          NaN        NaN     NaN               NaN
# 25%        NaN      NaN          NaN        NaN     NaN               NaN
# 50%        NaN      NaN          NaN        NaN     NaN               NaN
# 75%        NaN      NaN          NaN        NaN     NaN               NaN
# max        NaN      NaN          NaN        NaN     NaN               NaN
#
#        Neutral Sentiment Negative Sentiment Regulation Country  \
# count             255270             255270     255270  255270
# unique               753               4436       1080    2463
# top
# freq              253175             244838     253145  233323
# mean                 NaN                NaN        NaN     NaN
# min                  NaN                NaN        NaN     NaN
# 25%                  NaN                NaN        NaN     NaN
# 50%                  NaN                NaN        NaN     NaN
# 75%                  NaN                NaN        NaN     NaN
# max                  NaN                NaN        NaN     NaN
#
#        Positive Sentiment Measures
# count              255270   255270
# unique               2878      747
# top
# freq               248997   253517
# mean                  NaN      NaN
# min                   NaN      NaN
# 25%                   NaN      NaN
# 50%                   NaN      NaN
# 75%                   NaN      NaN
# max                   NaN      NaN
#
# Column names:
# ['timestamp', 'raw_text', 'Event', 'Company', 'Product', 'Location', 'Growth Trend', 'Competitor', 'Time', 'Financial Metrics', 'Neutral Sentiment', 'Negative Sentiment', 'Regulation', 'Country',
# 'Positive Sentiment', 'Measures']
#
# Data types of columns:
# timestamp             datetime64[ns, UTC]
# raw_text                           object
# Event                              object
# Company                            object
# Product                            object
# Location                           object
# Growth Trend                       object
# Competitor                         object
# Time                               object
# Financial Metrics                  object
# Neutral Sentiment                  object
# Negative Sentiment                 object
# Regulation                         object
# Country                            object
# Positive Sentiment                 object
# Measures                           object
# dtype: object
#
# Unique values in raw_text:
# ['$UMRX bouncing. EXTREMELY OVERSOLD #Coronavirus💸\n$DECN $OPGN $CODX $HTBX $TNXP $BA $APRN $JNUG $PCTL $BIEI $AAPL $NBY $UBER $WTRH $NOVN $TSLA $XSPA $INO $ASTC $MRNA $GPMT $SPXS $SPY $QQQ $NUGT
# $BURG $VXRT $TVIX $IBIO $ACB $TLRY $CLIR $BKYI $TOPS $NVAX $GME $TTOO $AYTU $TNXP💸📈 https://t.co/1R1e8PlfMw'
#  "This week's Expired Signals are now published (*early*). 🧠\nhttps://t.co/iPwC1npzlP\n\nAPR20 WK2 Stocks\n$TGT\n$DG\n$MCD\n$EMB\n$CMCSA\n$AMZN\n$AAPL\n$SPY\n\nAPR20 WK2
# Forex\n$EURAUD\n$CHFJPY\n$EURUSD\n$EURGBP\n$AUDJPY\n$XAUUSD\n$EURCHF"
#  "#tradeitforward MTI's Ask An Analyst with Chris Pulver, Gary Fichardt, Tyson Clayton - https://t.co/7SqFOkH15J\n\n100% FREE and FUN - great content for traders.\n\n#MTI #markettraders #stocks #forex
# #trading #tradingstrategy #WallStreet #CoronavirusOutbreak #SocialDistancing https://t.co/BA4HZIX0zP"
#  ...
#  'Family Offices Are Tired Of Conferences – Something Else Is Needed | Something else is needed indeed, a unique investment thesis that makes ... https://t.co/NSSWK2ZTlc #Collusion #FamilyOffice #ILPA
# #InstitutionalInvestors #LimitedPartners #NVCA #PrivateEquity #SP500 #Softbank https://t.co/zbV6gCCBpn'
#  '$KO Coca-Cola #Options #maxpain Chart, Open Interest Chart Update #OptionsTrading #OptionsFlow #optionstrade #optiontrading #stocks #stock #StockMarket #Investment #investing #invest #investor
# #investors #UOA https://t.co/I8hjTlmPov https://t.co/FTz0I96W18'
#  "Here's a dividends watchlist \nfor the 01/04/07/10 Payout Cycle:\n\n$T: $0.52 \n$BMO: $0.77\n$ABBV: $1.18 \n$VZ: $0.615\n$JPM: $0.90\n\nYou don't have to invest in dozens of stocks.\n\nJust make
# sure you're not missing out on earnings by investing in stocks from each payout cycle! https://t.co/xUWrXFQAtg"]
#
# Unique values in Event:
# ['Coronavirus' 'Expired Signals' '' ... 'mid-week chart session'
#  'Stocks Bubble' 'Mid-week chart session']
#
# Unique values in Company:
# ['GME' 'TGT, MCD, AAPL' 'MTI, MTI' ... 'NKE, JPM' 'Alumina Limited'
#  "PILGRIM'S PRIDE CORP, PPC, MOLSON COORS BEVERAG, TAP, ALBERTSONS COMPANIES, ACI, ACI: 6.3\n4. 🇺🇸 LEGEND BIOTECH CORPO, LEGEND BIOTECH CORPO, LEGN, SELECTQUOTE, INC., SELECTQUOTE, INC, SLQT"]
#
# Unique values in Product:
# ['' 'SPY, SLV' 'stocks, gold' ...
#  'AZN, DPZ, NFLX, JNJ, ABT, MRNA, TSM, MS, BAC' 'wave 5'
#  'T, BMO, ABBV, VZ, JPM']
#
# Unique values in Location:
# ['' 'Bali' 'Televison' ... 'Kandakadu' 'eastern shore' 'New York, JFK']
#
# Unique values in Growth Trend:
# ['' 'Long term bull market' 'Red gap' ... 'Advance Decline'
#  'Market rotation' 'monetization improvement']
#
# Unique values in Competitor:
# ['' 'HUI' 'Luca Maestri' ... 'experienced traders, unexperienced traders'
#  'Robinhood Group Of Novices' 'wynn, wmt, roku, tsla, twtt, uber, pto']
#
# Unique values in Time:
# ['' '1974' 'Jan 2019' ... 'due time' '8:16 pm EST' '1hr, 30m']
#
# Unique values in Financial Metrics:
# ['' 'equity valuations' 'Earnings' ... '99% win rate'
#  'user growth metrics' 'equity P/C ratio, bond yields']
#
# Unique values in Neutral Sentiment:
# ['' 'bullish' 'Not prudent' 'GLOBAL IMMUNITY' 'equitable' 'LUV' 'Nada'
#  'Bearish' 'W' 'bearish, bearish' 'TBD' 'AD' 'Faith' 'long' 'Bullish'
#  'ridiculous' 'greedy' 'IMO' 'IMO, IMO' 'Premature' 'LTBH' 'EASY'
#  'sparing' 'bearish' 'illogical' 'doubt' 'nuts' '🇨🇳' 'dystopian' '$APHA'
#  'neutral, bearish' 'rationality' 'CL' 'bearish, BULLISH, BEARISH' 'GL'
#  'v bearish' 'freedom, peace' 'lol' 'rich' 'moaty' '$DIS' 'hmmmm'
#  'cautious' 'Bipolar' 'bearish, bearish, bullish' 'divorced'
#  'selfish &amp; arrogant' 'NO' 'Pink' 'overvalued, undervalued' 'Resist'
#  'Islamophobic' '$SPY' 'Anti-Fragile' 'CBD' '$luv, luv' 'super bullish'
#  'bearish view' 'Insanity' 'F-U' '$XOM' 'Insane' 'bull side' 'dyor' 'Nope'
#  'RICH' 'Bullish, bearish' 'BULL' 'NY' 'up, up up up' 'RATIONAL'
#  'PATIENCE' 'B' 'E, S, Stupidity, Blindness' 'FAR TO PESSIMISTIC' 'Fairly'
#  'Neutral' 'neutral' 'green' 'extreme bullish' 'GREEN' 'Divided we fall'
#  'JK' 'Normal' 'Green' '$spx' 'ZERO' 'SUCKERS' 'reliance' 'sucessful'
#  'bullish, neutral' 'extreme bearish' '$dis' 'RS' 'american first'
#  'Fuck ‘Em' 'MIND' 'NOT normal' 'downjones' 'bullish, bullish'
#  'NEUTRAL, NEUTRAL' 'freedom' 'wealthy' 'G/N' 'BULLISH, BEARISH' 'YMMV'
#  'LOL' 'IGNORANT' 'insane' 'firmly bullish' '⬆️' '📈' 'OK' 'Rediculous'
#  'consistency' 'W, V' 'mambamentality' 'Selfish' 'GLTA' 'patience'
#  'short-sightedness' 'cheap' 'bullish, bearish' 'BEARISH, BEARISH' 'YOLO'
#  'BS' 'NOT DIFFERENT' '📉' 'bullish, bullish, bearish' 'plain dumb'
#  'fintwit' 'HAGW' 'GOVT' 'WHEW' 'greed' 'Not Cheap' 'STRONG' '$UNH'
#  'lock step, lock' 'V' 'attitude to risk' 'DYOR' 'vanity' 'chemi'
#  'hard NO, NO' 'mone' 'BK' 'Stupid' 'dumb' '$uso' 'WTF'
#  'bearish, bullishforstocks' 'optimistic' 'GREEDY' 'KINDLY' 'JMO' 'gay'
#  'BTD' 'doggy' 'YES' 'Ignorant' 'no-mans-land' 'Laughable' 'TBH'
#  'lukewarm side' 'unanchored' 'STUPID' 'Likely' 'STFU' 'ATH'
#  'Neutral, Neutral' 'long term optimist' 'below dirt' 'Negative'
#  'micro bullish' 'Germane' 'petty' 'insane, Insane' 'Ridiculous' 'Foolish'
#  'clueless' 'bull' 'Rich' 'Safe-haven' 'contrarian' 'irrational'
#  'conservative' '#bullish, bullish' 'Red, Green' 'SMH' 'ludicrous' 'TY'
#  'MUST' 'super bearish, bearish' 'yes' 'too hard pile' 'denial' 'NEUTRAL'
#  '💰' 'lameo' 'bizarro-world' 'Overly optimistic' 'freedo' 'Deep Red'
#  'BULLISH' 'lottos' 'magic' 'Not ideal, just being honest' 'fed'
#  'Zero privacy' 'trust' 'Green, Green is Green, Green' 'unreasonable'
#  'ARE, TOO' 'SATANIC' 'laissez Faire' 'Inevitable' 'UMMMMMM' 'frugal'
#  'bullish, bearsish' 'Unsustainable' 'Meh' 'skeptical' 'Consistency'
#  'fasing' 'crude' 'cyclical' 'pessimism' 'bullishness' 'crooked'
#  'aggressive' 'free' 'thin air, Thin air' 'exp' 'bearish extreme' '💎'
#  'la-la land' 'indu' 'true' 'Green, Red' 'not convinced' 'Red, red' '$LUV'
#  '$aapl' 'lite' 'All in' 'NEVER' 'PANIC' 'Optimism' 'All else equal'
#  'RISKY' 'Bullish, Bearish' 'L-Word' '$KO' 'TINA' 'Hopium'
#  'unamerican, arrogant' 'YEP' 'UNSTOPPABLE' 'yoy' 'Typical' 'AH' 'IMHO'
#  'Strong' 'absolute moron' 'UNCERTAINTY'
#  'Bullish, bullish, bearish, neutral' 'Brrrr' 'DIRT CHEAP' 'unthinkable'
#  'anticompetitive' 'cautiously optimistic' 'CHILLY' 'IRL LOL'
#  'reflexivity' 'BULL, BEAR' 'Sell - Bearish' 'rich, richenough' 'Red Zone'
#  'catholic' 'VIGILANT' 'notnow' 'Free' 'Neutral - Bullish, Bullish'
#  'cautiously bearish' 'NOT' 'LESS' 'crazy' 'POOR' 'momo'
#  'patience, persistence' 'filthy' 'NEGATIVE' 'Lazy' 'bullish, Bullish'
#  'Moat' 'stupid' 'bearish, bullish' 'Cautious' 'fuckchina' 'MSEP $DIS'
#  '$DIS, DIS' 'H, H' 'FFS' 'BTFD' 'KING' 'Corny' 'exuberant' 'Bearishness'
#  'DIS' '$MA$H' 'Despicable' 'No Reason' 'Ignorance' 'Bearish, Bearish'
#  'Soulless, Greed' 'Neither' 'zzzz' 'Momo' 'RED, GREEN'
#  'bullish, bullish. Also today marks A month of being bullish' 'DEMAND'
#  'Bearish, Dumbish' 'NO GREED' 'trump' 'Mentality' 'NIMBY' 'NOT cheap'
#  'NO POSITION' 'Lol'
#  'Bullish, Bullish, Bullish, Bullish, Bullish, Bullish, Bullish' 'ALLIN'
#  'gains' 'Extremely bearish, bearish' 'rationally, IWM' 'Flat' 'LUCKY'
#  'Green, Green' 'Green, Green, Green' 'richmindset' 'numb'
#  'Bullish, Gravy' 'UP' 'pessimistic' 'Hard to trust' 'not fair' 'nerdy'
#  'Absolutely ridiculous' 'Caution, caution' '+EV, EV' 'bat shit crazy'
#  'skepticism' '🐐' 'BEARISH, bearish, bullish' 'Green, Green, Green, Green'
#  'No' 'self-destructive' 'disingenuous' 'FIYAH' 'foolish' 'antifragile'
#  'Pessimism' 'G-reen' 'Blue' 'Bearishness, BEARISH' 'vain, stupid' 'weird'
#  'novi' 'shaaaaadyy' 'pessimism, skepticism, optimism, pessimism'
#  'independent' 'SAVE' 'self-importance' '$PFE' 'healthy' '$VZ $T'
#  'Cautious &amp; little nervous' 'Sneaky' 'YUM' 'unAmerican'
#  'VERY Bullish' 'Too Cheap' 'meh' 'Neutral - Bearish, Neutral'
#  'bearish, rich' 'Naked arrogance' 'LOW' 'green is green' 'Optimistic'
#  'Dis' 'NOPE' 'extremely bullish' 'Bullish, neutral' 'Grumpy, Cheery'
#  'White Supremacy' 'fair' 'No BS' 'Impatient' 'positive' 'Constructive'
#  'Bottom is in' 'red to green' '$ko $t $vz' 'idiotic' 'JAIL' 'luck'
#  'bullish nature' 'sociopathic' 'yep' '$es_f' 'FOMO, FOMO' 'zero reason'
#  'Bullish, Bullish, Bullish, Bullish, Bullish, Bullish, Bullish, Bullish, Bullish'
#  'Nuts' 'zippo' 'no doubt' 'mostly' 'bogus' 'RIP' 'nada' 'red'
#  '100% guilty' 'solid' 'Truth' 'MOST LIKELY' 'EXUBERANT' 'WEIRD' '🗳'
#  'politically biased' 'SCHWING, SCHWING' 'PLG' 'C' 'relentless'
#  'Long with Te' 'selfishness' 'bonos' 'Freedom' 'cons' 'FANTASY' 'YEP, XD'
#  'wrong' 'th' 'irrational, Fed' 'affor' '🤯'
#  'Maybe 90% Honesty, 90% Honesty, Honesty' 'no bias' 'BANG' 'Enron-like'
#  'woke' 'OBJECTIVE' 'Not extreme of course' 'staying patient' 'DUMB'
#  'NOT RESPECTING IT..\n\nIS MORONIC' 'Greed'
#  'confident tone, Confident tone' 'Bullish, Bearish, bearish'
#  'Not unreasonable' 'hawkish' 'Transparency' 'blue' 'hostile'
#  'dovish, hawkish' '💵' 'abundant' 'hell no' 'No bias' 'Not sustainable'
#  'wtf' 'Brutal' 'teste' 'hubris' 'NOT Greedy' 'ES_F' 'NUTs' 'Harmonic'
#  'motivated' 'Yellow zone' 'less risky' 'Reckless and stupid, Reckless'
#  'never wrong' 'Absurd' 'Undervalued' 'racional'
#  'mildly bullish, mega bullish' 'Random' 'Racist'
#  'bullish, #bearish, bearish' 'FTFU' 'REALLY' 'MIGHT' 'No dilution NONE'
#  'Prosper' 'bullish, open minded' 'SO OFTEN' 'Trade smart'
#  'ridiculous, Douchebags' 'ruthless' 'goldilocks' 'BLUE' 'Antiquated'
#  'Neutral, Neutral to bearish, bearish' 'Pathetic' 'bemore' 'sustainable'
#  'morally reprehensible' 'pessimism, greed' '$T' 'N' 'Pretty dumb'
#  'Curious' 'UR' 'Bullish, Bearish, Neutral' 'delusional' 'No Bull Sry'
#  'fugazi' 'like' 'Marxism, Marxism' 'yay, nay' 'DUH' 'Green, Green💚, Red'
#  'Crazy' 'aweso' 'P' 'TOO LATE' 'NOT SAFE' 'untrustworthy' 'bearish side'
#  'resilience' 'BULLISH, bearish' 'silly' 'ZZ' 'Risky' 'A LOT' 'Careful'
#  'unequivocally bullish, bullish' '#patience' 'ON' 'foolish + naive'
#  'maki' 'n/5' 'misogynist' 'Ne' 'anti american' 'bussiness' 'UNLIMITED'
#  'YUM, THW' 'F*ck you' 'Highly irresponsible' 'INSANE' 'IRRESPECTIVE'
#  'Dumb' 'Gangster' 'Kool-aid' 'bearish, Bullish'
#  'Neutral, Neutral - Bearish' 'Cultish' '$HUGE' 'TINA, WFH'
#  'bearish, bullish, neutral' 'black' 'gold-like' 'Delusion' 'D'
#  'Derision, Derision, derision' 'Bearish, bearish'
#  'Derision, Derision, derision, derision'
#  'Caution, #skepticism, skepticism' 'YEP, YEP, LOL, WOW' 'KISS' 'NBD'
#  'over-bullish, IMHO, IMHO' 'nothing is 100%' 'F' 'un-investible'
#  'nothing crazy' 'trusted' 'BEARISH' 'Hell, No' 'NO WAY' 'Meaningless'
#  'impulsive' 'Brearish' 'liberal' 'green, red' 'Red' 'bullish side'
#  'un-American' 'phantombillions' 'smar' 'Bearish, Neutral'
#  'Pavlovian response' 'weaksauce bruh' 'underrated' 'IDK' 'ridic'
#  'Green Green' 'equality' 'ne' 'Conservative' 'Nothing' 'RED' 'Heavy bias'
#  'too big to fail' 'fomo' 'TBC' 'FREE' 'unlimited' '$Fb' '$IDEX'
#  'unfashionable' 'blasé' 'OPPORTUNITY' 'Imo' 'booolish' 'Low T' 'nasty'
#  'Be cautious, Be' 'Neutral-to-Positive' 'MMT is good' 'very popular'
#  'Sopy' 'Cheap' 'VERY' 'bearish, Bearish' 'ommgggg' 'UNH'
#  'bearish, bearish, Bullish' 'hesitant' 'WL' 'no greed, no fear'
#  'Patience' 'complacency' 'Yellow' 'concious' 'SILENT' 'KO' 'DD, DD'
#  'cute' 'Bias' 'Bearish, Bullish' 'not natural' 'mega bullish' 'Absurdity'
#  'Neutral - Bearish, Neutral, Bearish' 'LONG' 'KR, CHGG' 'dork' 'BRRRRRRR'
#  'HELLO' 'Hypocrites' 'criminally stupid' 'Neutral, Bearish' 'RARE' 'WHAT'
#  'bearishness, bearishness' 'no' '🔑' 'NFP' 'DISCIPLINE, freedom'
#  'no judgment' 'negativ bias' 'HOLD, ADD' 'bearish bias' '💪'
#  'racist, racist. Ridiculous. Can they b more creative to use racism, racism'
#  'respect' 'anti-American' '🤙' 'FDP' 'alone' 'brrr' 'MAGA MAGA, MAGA'
#  'choppy' 'Absolutely not' 'Bullish, LOL' 'RT, ❤, ❤️'
#  'Bullish, Bearish, Bearish, Bearish, bearish' 'positivity' 'L/T'
#  'moral high ground, LOL' 'WAY EARLY' 'serious' 'CHEAP' 'longterm' 'Zero'
#  'WOO, WOO' '100%' 'Neutral - Bearish, Bearish' 'Pffft' 'Green, Green🌱'
#  '👍, 👎' 'Nasty' 'arrogance' 'greenflag' '🤑' 'Profane' 'NEED'
#  'Bullish, bullish, bearish' 'LMFAOOOO' 'True' 'Cautiously Bullish'
#  'ESG, ESG' 'Pessimistic' 'selfish' 'CK' 'Insane IMO' 'bulky' 'boohoo'
#  'patriotic' 'kosher' 'Yellow LEVEL' 'shit crazy'
#  '💰, 🕰, 💰, 🕰, 🕰, 🕰&amp;💰, 💰' 'bananas' 'not blind faith'
#  'Bearish, Bullish, Neutral' 'emotional' 'impatient' 'underrated, cheaper'
#  'gree' 'F$^%&amp; hard' 'overly bullish, bullish' 'tbd' 'Caveat Emptor'
#  'dumb, duumb' 'Less is best' 'Silliness' '$LOW'
#  'mrkt strong, mrkt, BTD, BTD BTD, mrkt' 'LiberalismIsTheRealPandemic'
#  'defensive nature' 'parabolic' 'N/A' 'Seldom' 'Unlikely, Unlikely' 'bias'
#  'Long bias' 'cheddar' 'CONSERVATIVE' 'epoch of incredulity' 'Nuh-nuh'
#  '100% #transparency' 'supreme' 'Monogamy' '👻' 'duh' 'Sure' 'un-loved'
#  'bullishly' 'Not Indefinitely'
#  'Bullish, Bearish, Bearish, Bearish, bullish']
#
# Unique values in Negative Sentiment:
# ['' 'Bearish, Bullish' 'bullishness' ... 'retard shit' 'BUY signal'
#  'Warning signal']
#
# Unique values in Regulation:
# ['' 'law, law' 'NAFTA' ...
#  'UNITLESS ACTIVITY ASSESSMENT AND ASSOCIATED METHODS' 'EU tax bill'
#  'UK Visa']
#
# Unique values in Country:
# ['' 'US' 'U.S., U' ... 'SHANGHAI' 'Singapore, US, US' 'usmarkets']
#
# Unique values in Positive Sentiment:
# ['' 'Great deal' 'Happy' ... 'Good point' 'Congrats, Congrats👍'
#  'positive signal']
#
# Unique values in Measures:
# ['' 'technical analysis' 'anti body rapid test' 'Immunological Benefit'
#  'Price Discovery' 'human trials' 'assay results' 'stop formulas'
#  'Scientific Sampling' 'technical indicators' 'Staff Bonuses'
#  'econ fundamentals' 'serological population testing' 'user tracking'
#  'position sizing' 'set up quality' 'antigen testing' 'share tips'
#  'entry and exit parameters' 'market crash indicators'
#  'entries &amp; exits trade triangles' 'Filters' '6 Tips'
#  'unemployment benefit claims' 'Fibonacci Lines, Support &amp; Resistance'
#  'Face Mask Requirements' 'Fibonacci Lines' 'Risk Management'
#  'Intrinsic Value Analysis' 'industrial comparisons'
#  'Relative Strength Scan' 'testing'
#  'Risk Management, study of virus characteristics' 'REAL-LIFE EXAMPLES'
#  '4 Rules of Personal Finance' 'Probability of expiring cone'
#  'Cryptography spec' 'risk management' 'PE valuation analysis' 'goals'
#  'time-stamped based reporting' 'four steps' 'business benefits'
#  'litmus test' 'fibonacci Lines, Support &amp; Resistance' 'safeguards'
#  'surveillance' 'Risk Mgmt' 'Borrowing Standards' '7-Day Options Power'
#  'puts' 'Three Tips' 'Patient Enrollment'
#  'Margin of Safety, Circle of Competence' 'margin of error'
#  'standards/requirements' 'determinants of success' 'liquidity filter'
#  'public health workflows' 'Risk management, risk tolerance'
#  'margin requirement' 'Building permits' 'stress tests' 'tests, tests'
#  'Fundamental re-rating' 'Risk management' 'balance sheet talks'
#  'antibody testing' 'elective procedures' 'vaccine work'
#  'wealth management' 'Operational Sales Guidance' 'bottom-up analysis'
#  'payroll costs' 'input constraints' 'national solutions'
#  'support measures' 'benchmark tests' 'Stress tests'
#  'scientific breakthroughs' 'family PLAN' 'Automatic Data Processing'
#  '1-drop blood testing' 'fundamentals' 'key factors' 'Research Reports'
#  'surveys' 'infrastructure stimulus' 'Before &amp; After Checklist'
#  'Recycling Test Results' 'trading rules' 'Investment advisory'
#  'monetary policy measures' 'reopening guidelines' 'beta test' 'analytics'
#  'lending standards' 'valuation metrics' 'protective measures'
#  'risk models' 'health care efforts' 'risk range revisions'
#  'Drugs pipeline' 'drug development' 'Sentiment Indicators'
#  'fibonacci Lines' 'Patient Visits' 'unemployment benefits'
#  'Efficient Market Hypothesis' 'emergency measures'
#  'liquidity-boosting measures'
#  'wellness checks, voluntary temperature taking' 'Strategy assessment'
#  'stop losses' 'control arm, control arm' 'circle targets'
#  'Stimulus check' 'massive testing' 'statistical validity' 'test results'
#  'eye test' 'standards' '3 building blocks'
#  'Stop loss placement \n- entry timing' 'Human behavioral patterns'
#  'Proper position sizing' 'medical breakthrough'
#  'mental coaching, proof of concept' 'tax benefits' 'UI benefits'
#  'balance sheets' '5 Steps' 'Big picture analysis' 'Stimulus Check'
#  'abnormal volume' 'KPI' 'Upgrades &amp; Downgrades' 'COVID-19 test'
#  'valuation check' 'social welfare strategies'
#  'shareholder voting, shareholder resolutions, shareholder voting'
#  'disease mitigation' 'DataDriven decisions' 'Covid tests'
#  'stress testing' 'risk minimization' 'disinformation program'
#  'Infrastructure Program' 'Volatility Filters' 'safety concerns'
#  'randomized controlled inpatient clinical trials' 'runtime value checks'
#  'uneployment  checks' 'gap fill targets' 'Technical analysis'
#  'performance bonuses' 'admin expenses' 'margin call requirements'
#  'Fibbonacci extensions' 'shelter-in-place demands'
#  'Impairment Detection Pilot' 'case studies' 'pre-clinical studies'
#  'set ups' 'temperature checks' 'trials results'
#  'cardio and muscle load data, sleep tracking' 'vaccine trials'
#  'econ indicators' 'Monthly activity gauges' 'intervention levels'
#  'technical signals' 'healthcare standards' 'optics' 'Face Masks'
#  '3 Secret Ways' 'executive bonuses' 'correction targets'
#  'On-Demand Location Visit Conversion Metrics'
#  'Tools For Reducing Market Exposure' 'gas price formula'
#  'Production and cost guidance' 'borrowing standards' 'stop out levels'
#  'Volume analysis' 'forensic audits' 'backtest' 'data practices'
#  'valuations' 'Margin of Safety' 'risk mgmt'
#  'Long term digitisation benefit' 'statistics' 'valuation'
#  'Precise technicals' 'addiction recovery' 'Stage 2 breakouts'
#  'cash flow analysis' 'macro analysis' 'Measured Move Targets' 'ratings'
#  'health claims' 'reward analysis' 'Power of Forward Guidance' 'Bailouts'
#  'Risk/reward setup' 'predictive analytics' 'Fractal Analysis' 'targets'
#  'Coronavirus Monitoring' 'breakeven' 'prop timing models'
#  'virus resolution' 'clear head' 'Potential Prognostic Biomarkers'
#  'Ratings' 'Antibody Tests' '1 mission' 'User equipment positioning'
#  'Cost efficiency programs' 'peso/leverage stress test' 'data analysis'
#  'chart candles' 'risk indicators' 'Personal Protection Protocols'
#  'pipeline progress' 'physcian visits' 'pandemic safety practices'
#  'patterns' 'non-GAAP measures, non-GAAP measures' 'rational expectations'
#  'safe and compliant protocols' 'fibs' 'investment tips'
#  'Chinese food intolerance tests' 'Q experiment'
#  'Technical Analysis Score Update' 'fixed/variable cost analysis'
#  'TRANSACTIONAL LICENSING' 'Due Diligence' 'capital allocation policies'
#  'ER reports, foward guidances' 'Risks &amp; Tests' 'Data analytics'
#  'Capital preservation' 'Stop loss' 'clinical trials results'
#  'marketing budgets' 'public health aspects' 'Vaccine updates'
#  'cost efficiency' 'Thechnical analysis' 'risk diversification'
#  'solvency test' 'learning models' 'EPS Guidance' 'market movers'
#  'Margins' 'Higher order intake assumptions' '20 day SMA'
#  'pantry de-loading' 'key trend filter' 'anti-body test' 'STI test'
#  'health benefits' 'standard parameters' 'facial recognition data'
#  'fundamental analysis' 'levels' 'rules, watchlist, setups &amp; triggers'
#  'dividends formula' 'drug approvals' 'price predictions' 'Temp checks'
#  'health precautions, temperature screening' 'temperature screening'
#  'density control meas'
#  'Density control, guest capacity control, health prevention measures'
#  'Temperature checks' 'temperature checks, contract tracing'
#  'health measures' 'contact tracing'
#  'density control measures, health screenings' 'trade recaps'
#  'common sense risk management' 'Treatment implications'
#  'internal measures' 'price ladder' 'key test' 'key metrics'
#  'traditional metrics' 'Sentiment Survey' 'margin guidance'
#  'Consensus Recommendation' 'investment lens' 'five primary factors'
#  'Risk Reduction Playbook' 'yield curve control'
#  'probabilistic assessments' 'Covid19 death toll projections'
#  '3 Simple steps' 'QUALITY TRADES' 'capital preservation'
#  'volume profile study' 'sentiment readings' 'Enhanced Safety Measures'
#  'optional targets, preclinical work' 'policy response'
#  'cash conservation measures' 'efficacy bar' 'stats-based responses'
#  'survey responses' 'health initiatives' 'capital allocation procedures'
#  'Face ID Mask Updates' 'risk management, Risk management'
#  'ER projections' 'Temperature Checks' 'EM surveys' 'guidelines'
#  'cost cutting measures' 'employee testing' 'Predictive Analytics'
#  'free audience analytics' 'sorting purposes' 'margin of safety'
#  'performance comparisons' 'option chain analysis' 'healthcare spending'
#  'criteria' 'warrantless browser searches' 'data mining and tracking'
#  'tax deductions' 'indicators' 'FACT-CHECKS' 'small business stress test'
#  'ETF Intelligence' 'Execution/Target Zones' 'ECONOMIC PROJECTIONS'
#  '3002 support' 'protocols, PPE production, testing advance'
#  'chart comparisons' 'key indicators' 'Poker Fundamentals'
#  'saliva-based detection test' 'voting power'
#  'technical analysis scenarios' 'sub group analysis' 'stop loss hits'
#  '4 simple steps' 'fundamentals &amp; tech. indicators'
#  'Tumor Response Rates' 'Clinically Meaningful Tumor Response Rates'
#  'Advertising Impressions Intelligence' 'Quality metrics'
#  'Position sizing' 'developer education' 'shortable resistances'
#  'Supply Chain Tracking' 'balance sheet needs'
#  'System checks and preparations' 'pre market scans' 'stimulus measures'
#  'Security Fixes' 'executive compensation incentives' 'encryption plan'
#  'head count, head' '10 Golden Rules' 'subgroup analysis'
#  'Manufacturing surveys' 'Filter Criteria' 'stress test' 'Vaccine watch'
#  'Market Profile' 'drug trial results' 'VACCINE PROGRESS'
#  'category breakouts' 'cross-references' 'equity weighting'
#  'quarantine expenses' 'antibody test' "gov't investigations" 'hr wage'
#  'Invalidation Levels' 'scrutiny' 'analyst upgrades' 'vaccine play'
#  'clinical trials' 'lobbying accountability' 'technical factors'
#  'gap rules' 'cost saving measures' 'stock analysis' 'Risk gauge'
#  'risk control' 'reality check correction' 'ATHs' '3 Principles'
#  'filters &amp; criteria' 'Technical Analysis' 'risk tolerances'
#  'ECB stress test'
#  'COGS analysis, COGS analysis &amp; supply chain rationalisation'
#  'temp checks' 'Safety Factor' 'background checks'
#  'Previous valuation methods, valuation methods'
#  'fleetwide safety programs' 'RSI concepts' 'Fibonacci ratios'
#  'sentiment surveys' 'Autoimmune combo potential' 'studying purposes'
#  'learning &amp; communication issues' 'safety measures'
#  '5 Lessons Learned' 'data caps' 'Sentiment analysis' 'Investing Tips'
#  'capital protection' 'ppl' 'Voters Registrations'
#  'Risk control/management' 'Volume Spread Analysis' 'YOLO indicators'
#  'COGS analysis, Logisitics' 'volume pattern analysis' 'marketing efforts'
#  'swing study' 'cutting losses, cutting losses, cutting losses'
#  'deep research' 'technical reasons' 'Vaccine R&amp;D'
#  'technical analysis, technical analysis' 'Stop Loss Rules' 'rules'
#  'efficacy endpoints' 'multi-timeframe analysis' 'IP protection'
#  'Indicators' 'sound management principles'
#  'safety assessment, safety assessments' 'proof of concept'
#  'safety\nStudies' 'golden handcuffs' 'employee engagement'
#  'precision science' 'yield curve controls' 'Phase 2 trials'
#  'Mobile Wallets Survey' 'Yield curve control'
#  'earnings expectations treadmill' 'inputs, inputs' 'facial recognition'
#  'bug reports' 'policy measures' 'cost-savings measures'
#  'survival benefits' 'Five great strategies' 'consortium test'
#  'forward testing' 'Full analysis' 'stop loss'
#  'Rules &amp; Tactics, Rules and Tactics, Rules and Tactics' 'mechanics'
#  'RSI Convergence Lines' 'stress-test results' '4 steps'
#  'balance sheet analysis' 'Facial Recognition' 'stop Loss'
#  'maximum daily loss' '25k-75k challenge' 'patient education'
#  'worker safety' 'benchmarks' 'stochastics' 'chart alerts'
#  'data advantage' 'technical analysishttps' 'Broker comparisons'
#  '3 SIMPLE metrics' 'Dollar-cost averaging' 'Asset correlations'
#  'Technical Levels' 'rectal drug considerations' 'measuring parameters'
#  'allocation' 'breast cancer study results'
#  'Discipline, Timing, discipline' 'Performance monitoring' 'security'
#  'Stimulation packages' 'capital stress tests' 'Risk management system'
#  'Discipline Factor' 'anti-trust probes' '5 Reasons' 'policy taps'
#  'Cost control skills' 'psychological signals' 'safety &amp; efficacy'
#  'metrics' '7 simple steps' 'combination of variables' 'GTS Search Fixes'
#  'money laundering defenses' 'SMART goals' 'eligibility criteria'
#  'election transparency measures' 'profit-and-loss plan' 'tax tips'
#  'audit' '3 Powerful Strategies' 'learning curve' 'volatility filter'
#  'indicators, indicators' 'MACHINE LEARNING CLASSIFICATION'
#  'balance rules' 'macro fundamentals' 'Key metrics' 'virus timing'
#  'instructions' 'day trading requirements' 'hospitalization data'
#  'reopening safety protocol' 'Treatment preferences'
#  'SENSITIVITY ANALYSIS' 'Census' 'Quality filter' 'COVID testing'
#  'stop loss, stop loss, stop loss, stop loss' 'capital requirements'
#  'market validation' 'exclusion list' 'logistics' 'privacy upgrades'
#  'Yield Curve Control' 'fitness tracking' 'Cryptojacking Detection'
#  'Mid-year catalysts' 'critical voting information' 'economic formula'
#  'Safety and Immunogenicity Objectives, Immunogenicity Objectives'
#  'Stress Tests' 'attention-related abilities' 'unconventional gauges'
#  'CQC approvals' 'Account Switching Incentives' 'Encryption plans'
#  'Algorithms' 'safety assessments'
#  'credit decisions, account verification' 'recommendations algorithms'
#  'factor test' 'fact check information'
#  'Systems and methods for non-pulsatile blood volume measurements'
#  'case study' 'stress test results' 'rewards' 'chart requests'
#  'security efforts' 'ref ATH 2722 test' 'public health decisions'
#  'Stress test results' 'content moderation practices' 'New Data Analyses'
#  'Trading rules' 'Mathematical Algorithms'
#  'Environmental Impact Assessment' 'subject tracking range' 'cost savings'
#  'Fundamental Analysis Score Update' 'tracking results'
#  'softball stress test, Stress test results' 'Reserve requirements'
#  'Short covering' 'softball stress test' 'Investment Implications'
#  'safety warnings' 'Bank Stress Tests' 'bank stress tests'
#  'support levels' 'drill results' 'Course correction' 'chat history'
#  'Monthly candles' 'FED fiscal soundness tests' 'civil rights audit'
#  'racial justice work' 'running count' 'bank stress test results'
#  'minimum wage' 'Fed Stress Test' 'Stress Test Results'
#  'stress test restrictions' 'Valuation comparisons'
#  'Position sizing, stop losses' '5 Simple Trading Rules'
#  '1:1 randomization' 'benchmark' 'top 3 functions' 'CAPTURE SAVINGS'
#  'treatment updates' 'inside track' 'sleep tracking'
#  'distance learning updates' 'Fed PUT' 'post-stress tests'
#  'health and safety' 'Pattern Recognition' 'independent clinical studies'
#  'Economic analysis, Industrial analysis, Analysis of 5 year data'
#  'Price action verification' 'Buildingsforbomb training' 'Impact Analysis'
#  '5 minute resistance levels' 'corrective count' 'technical triggers'
#  'weekly cycle analysis' 'Lithium-ion Battery Recycling Efforts'
#  'triangle support' 'TECHNICAL ANALYSIS SKILLS' 'stock trading watchlist'
#  'pre-market analysis' 'data-collection practices'
#  'fire prevention strategies' 'fault lines, range plays'
#  'universal virus efficacy' 'unifying health records, health records'
#  'antibody results' 'HR' 'Vaccine' 'moving averages, support/resistance'
#  'exposure and risk tolerance' 'quantitative means' 'lagging indicators'
#  'safety study' 'technical views' 'recertification tests' 'vaccine plan'
#  'safety plan' 'product discovery' 'TESTS, tests' 'Covid testing'
#  '7 steps' 'Additional Surveillance Measures' 'INSIDE INFO'
#  'Scaling and Risk Reward' 'dose escalations' '15 question survey'
#  'market analysis' 'tiers'
#  'Technical analysis continues to fail most historic efficacy tests, historic efficacy tests, efficacy tests'
#  'mgmt reactions, institutional analysis' 'Personal Fitness Data'
#  'algorithms' 'treatment protocols' 'adequate testing'
#  'Important indicators' 'technical analysis, market fundamentals'
#  'fundamental screens' 'cardholder verification limit' 'unlimited tools'
#  'Profit Guidance' 'back-testing' 'Metrics' 'data collection'
#  'Priceaction and support and resistance strategies' 'Clinical Outcomes'
#  'SPOF test' 'shareholder expectation treadmill' 'Fibonacci  levels'
#  'tolerance level' 'Real Time Analytics' 'Capacity Limits' 'TSA Numbers'
#  'Hospitalizations' 'vaccine timeline' 'educational indicators'
#  'accountability metrics' '10 demands' 'candlestick confirmation'
#  'Relative Bias Filter' 'back test' 'TRADING PROGRAMS' 'exit rules'
#  'subjective technical analysis' 'media sentiment analytics'
#  'Diversification' 'risk/reward analysis' 'Five Easy Steps'
#  'vaccine progress' 'initial tests' 'touchless payment biometrics'
#  'Name recognition' 'Fundamental analysis' 'portfolio mgmt'
#  'market internals' 'employment income solution'
#  'Balls to hold, balls to hold' 'Options Strategies'
#  'intra-day cash flow tactics' 'Maths' 'Head-To-Head Survey'
#  'Patent Analytics' 'safety precautions' 'Basics of price actions'
#  'search benefits' 'vaccine efficacy, advanced trials'
#  'Covid daily percent positive test rate' 'COVID Antigen Assays'
#  'stimulus packages' 'frequency control' 'Laboratory Results'
#  'Battery Certifications' 'Internal investigations' 'cost structure'
#  'pre-human trials' 'random meeting IDs' 'checkout lines'
#  'distance from a camera estimation' 'Acid Test Ratio' 'stop limits'
#  'Financial Data Screening' 'DQs' 'safety protocols'
#  'technology commitments' 'Provision For Credit Loss' 'Vaccine Efficacy'
#  'Content-based tactile outputs' 'diversification benefits'
#  'cohort analysis' 'proper position sizes' 'Passive Fingerprints'
#  'vaccine efficacy' 'Elective Payouts' 'audit opinions'
#  'Tabular Data Queries' 'fibonacci lines' '3 cures'
#  'Surface Selective Sampling' 'Current Ratio' 'mask mandates'
#  'Provision For Credit Losses' 'Speculations'
#  'Technical Analysis, Fundamental Analysis']
#
# Null values count in each column:
# timestamp             0
# raw_text              0
# Event                 0
# Company               0
# Product               0
# Location              0
# Growth Trend          0
# Competitor            0
# Time                  0
# Financial Metrics     0
# Neutral Sentiment     0
# Negative Sentiment    0
# Regulation            0
# Country               0
# Positive Sentiment    0
# Measures              0
# dtype: int64
#
# Out: None
# ...
#
#   print("Findings and plan have been updated.")
#  ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Findings and plan have been updated.
#
# Out: None
# [Step 1: Duration 30.22 seconds| Input tokens: 21,389 | Output tokens: 1,343]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing this code: ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   import pandas as pd
#   import matplotlib.pyplot as plt
#   from collections import Counter
#
#   # Load the data
#   df = load_filter_dataframe()
#
#   # Convert timestamp to datetime
#   df['timestamp'] = pd.to_datetime(df['timestamp'])
#
#   # Analyze temporal distribution
#   daily_counts = df.resample('D', on='timestamp').size()
#
#   # Plot temporal distribution
#   plt.figure(figsize=(12, 6))
#   daily_counts.plot()
#   plt.title('Temporal Distribution of Data')
#   plt.xlabel('Date')
#   plt.ylabel('Number of Entries')
#   plt.tight_layout()
#   plt.savefig('temporal_distribution.png')
#   plt.close()
#
#   # Identify top events and companies
#   top_events = Counter(df['Event']).most_common(10)
#   top_companies = Counter(df['Company']).most_common(10)
#
#   # Analyze sentiment distribution
#   sentiment_cols = ['Neutral Sentiment', 'Negative Sentiment', 'Positive Sentiment']
#   sentiment_counts = df[sentiment_cols].notna().sum()
#
#   # Update findings
#   findings_content = """
#   # Data Analysis Insights
#
#   ## Temporal Distribution
#   - A plot of the temporal distribution has been saved as 'temporal_distribution.png'
#   - Key observations from the plot:
#     (Please describe any notable patterns or trends you observe in the plot)
#
#   ## Top 10 Events
#   {}
#
#   ## Top 10 Companies
#   {}
#
#   ## Sentiment Distribution
#   {}
#
#   ## Key Features
#   1. Timestamp: Crucial for temporal analysis and trend identification
#   2. Event: Captures specific occurrences or topics (11,153 unique values)
#   3. Company: Identifies discussed companies (75,031 unique values)
#   4. Sentiment columns: Provide insights into public perception
#   5. raw_text: Contains detailed information for text analysis
#   6. Measures: Includes various financial and analytical metrics
#
#   ## Feature Significance
#   - Timestamp: Essential for tracking trends over time
#   - Event and Company: Key for categorizing discussions and analyzing industry-specific trends
#   - Sentiment columns: Valuable for gauging public opinion and market sentiment
#   - raw_text: Rich source of information for detailed content analysis
#   - Measures: Potential for correlating financial metrics with other variables
#
#   Next steps should include more detailed analysis of these key features and their relationships.
#   """.format(top_events, top_companies, sentiment_counts.to_dict())
#
#   write_findings(content=findings_content, append=True)
#
#   print("Updated findings with temporal distribution analysis and key feature identification.")
#  ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Updated findings with temporal distribution analysis and key feature identification.
#
# Out: None
# [Step 2: Duration 22.49 seconds| Input tokens: 40,963 | Output tokens: 2,157]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
